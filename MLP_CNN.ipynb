# %%
import pandas as pd
data=pd.read_csv("only_mfcc.csv")
print(data.shape)


y_data=data['Emotion']
print(y_data.shape)
x_data=data.iloc[:,0:125]
print(x_data.shape)
# Out:
# (1436, 128)
# (1436,)
# (1436, 125)

# %%
from  sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_data,y_data,test_size=0.33,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (962, 125)
# (474, 125)
# (962,)
# (474,)

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder()

y_train = np_utils.to_categorical(lb.fit_transform(y_train))
y_test = np_utils.to_categorical(lb.fit_transform(y_test))


x_traincnn =np.expand_dims(x_train, axis=2)
x_testcnn= np.expand_dims(x_test, axis=2)

# %%
model = Sequential()

model.add(Conv1D(256, 5,padding='same',
                 input_shape=(125,1)))
model.add(Activation('relu'))
model.add(Conv1D(128, 5,padding='same'))
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=(8)))
model.add(Conv1D(128, 5,padding='same',))
model.add(Activation('relu'))
#model.add(Conv1D(128, 5,padding='same',))
#model.add(Activation('relu'))
#model.add(Conv1D(128, 5,padding='same',))
#model.add(Activation('relu'))
#model.add(Dropout(0.2))
model.add(Conv1D(128, 5,padding='same',))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dense(16))
model.add(Activation('softmax'))
opt = keras.optimizers.rmsprop(lr=0.00001, decay=1e-6)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_5 (Conv1D)            (None, 125, 256)          1536
# _________________________________________________________________
# activation_6 (Activation)    (None, 125, 256)          0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 125, 128)          163968
# _________________________________________________________________
# activation_7 (Activation)    (None, 125, 128)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 125, 128)          0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 15, 128)           0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 15, 128)           82048
# _________________________________________________________________
# activation_8 (Activation)    (None, 15, 128)           0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 15, 128)           82048
# _________________________________________________________________
# activation_9 (Activation)    (None, 15, 128)           0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1920)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                30736
# _________________________________________________________________
# activation_10 (Activation)   (None, 16)                0
# =================================================================
# Total params: 360,336
# Trainable params: 360,336
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
cnnhistory=model.fit(x_traincnn, y_train, batch_size=16, epochs=150, validation_data=(x_testcnn, y_test))
print(max(accuracy))
# Out:
# Train on 962 samples, validate on 474 samples
# Epoch 1/150
# 962/962 [==============================] - 6s 6ms/step - loss: 4.3956 - acc: 0.0676 - val_loss: 3.1068 - val_acc: 0.1076
# Epoch 2/150
# 962/962 [==============================] - 4s 4ms/step - loss: 2.9710 - acc: 0.0790 - val_loss: 2.7825 - val_acc: 0.0696
# Epoch 3/150
# 962/962 [==============================] - 4s 4ms/step - loss: 2.8911 - acc: 0.0780 - val_loss: 2.7323 - val_acc: 0.0992
# Epoch 4/150
# 962/962 [==============================] - 4s 4ms/step - loss: 2.8387 - acc: 0.0884 - val_loss: 2.7391 - val_acc: 0.1139
# Epoch 5/150
# 962/962 [==============================] - 4s 4ms/step - loss: 2.7979 - acc: 0.0967 - val_loss: 2.7083 - val_acc: 0.1160
# Epoch 6/150
# 962/962 [==============================] - 5s 5ms/step - loss: 2.7922 - acc: 0.0832 - val_loss: 2.7040 - val_acc: 0.0886
# Epoch 7/150
# 962/962 [==============================] - 4s 4ms/step - loss: 2.7761 - acc: 0.0946 - val_loss: 2.6634 - val_acc: 0.1139
# Epoch 8/150
# 962/962 [==============================] - 5s 5ms/step - loss: 2
150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.5063 - acc: 0.4626 - val_loss: 1.7858 - val_acc: 0.3418
# Epoch 125/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.5240 - acc: 0.4532 - val_loss: 1.7561 - val_acc: 0.3629
# Epoch 126/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.5131 - acc: 0.4636 - val_loss: 1.7474 - val_acc: 0.3713
# Epoch 127/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4917 - acc: 0.4574 - val_loss: 1.7283 - val_acc: 0.3439
# Epoch 128/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4920 - acc: 0.4667 - val_loss: 1.8020 - val_acc: 0.3143
# Epoch 129/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4781 - acc: 0.4782 - val_loss: 1.7844 - val_acc: 0.3523
# Epoch 130/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4859 - acc: 0.4563 - val_loss: 1.7566 - val_acc: 0.3376
# Epoch 131/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4814 - acc: 0.4657 - val_loss: 1.7242 - val_acc: 0.3734
# Epoch 132/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4844 - acc: 0.4761 - val_loss: 1.7863 - val_acc: 0.3143
# Epoch 133/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4647 - acc: 0.4834 - val_loss: 1.7371 - val_acc: 0.3565
# Epoch 134/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4713 - acc: 0.4854 - val_loss: 1.7106 - val_acc: 0.3608
# Epoch 135/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4554 - acc: 0.4823 - val_loss: 1.7174 - val_acc: 0.3797
# Epoch 136/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4522 - acc: 0.4709 - val_loss: 1.7233 - val_acc: 0.3502
# Epoch 137/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4521 - acc: 0.4699 - val_loss: 1.6936 - val_acc: 0.3797
# Epoch 138/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4489 - acc: 0.4813 - val_loss: 1.7378 - val_acc: 0.3629
# Epoch 139/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4533 - acc: 0.4678 - val_loss: 1.7138 - val_acc: 0.3692
# Epoch 140/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4394 - acc: 0.4927 - val_loss: 1.7149 - val_acc: 0.3861
# Epoch 141/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4382 - acc: 0.4834 - val_loss: 1.6977 - val_acc: 0.3734
# Epoch 142/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4312 - acc: 0.4886 - val_loss: 1.7297 - val_acc: 0.3439
# Epoch 143/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4360 - acc: 0.4896 - val_loss: 1.7140 - val_acc: 0.3819
# Epoch 144/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4276 - acc: 0.4938 - val_loss: 1.7099 - val_acc: 0.3418
# Epoch 145/150
# 962/962 [==============================] - 4s 4ms/step - loss: 1.4309 - acc: 0.4906 - val_loss: 1.7129 - val_acc: 0.3544
# Epoch 146/150
# 962/962 [==============================] - 7s 7ms/step - loss: 1.4200 - acc: 0.4813 - val_loss: 1.6790 - val_acc: 0.3608
# Epoch 147/150
# 962/962 [==============================] - 10s 10ms/step - loss: 1.4210 - acc: 0.4958 - val_loss: 1.6828 - val_acc: 0.3734
# Epoch 148/150
# 962/962 [==============================] - 9s 9ms/step - loss: 1.3979 - acc: 0.5042 - val_loss: 1.7046 - val_acc: 0.3819
# Epoch 149/150
# 962/962 [==============================] - 8s 8ms/step - loss: 1.4176 - acc: 0.4906 - val_loss: 1.6977 - val_acc: 0.3650
# Epoch 150/150
# 962/962 [==============================] - 8s 9ms/step - loss: 1.4053 - acc: 0.4865 - val_loss: 1.6779 - val_acc: 0.3629
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-d80b93e5de49> in <module>
#       1 cnnhistory=model.fit(x_traincnn, y_train, batch_size=16, epochs=150, validation_data=(x_testcnn, y_test))
# ----> 2 print(max(accuracy))
#
# NameError: name 'accuracy' is not defined
